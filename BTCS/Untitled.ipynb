# %%
import matplotlib
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
import os

# %%
os.listdir("./data/snapshots/")
# Out:
# ['0.0006_10_5_5_0.0002_0.txt',
#  '0.0004_10_5_5_0.0002_0.txt',
#  '0.0008_10_5_5_0.0002_0.txt',
#  '0.0002_10_5_5_0.0002_0.txt']

# %%
t_snap = np.linspace(0.000002,0.05,10)
string = ''
for e in t_snap:
    string = string+','+str(e)
print string
# Out:
# ,2e-06,0.00555733333333,0.0111126666667,0.016668,0.0222233333333,0.0277786666667,0.033334,0.0388893333333,0.0444446666667,0.05

# %%
for nam in sorted(os.listdir("./data/snapshots/")):
    data = np.loadtxt("./data/snapshots/"+nam)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_title(nam)
    plt.imshow(data, interpolation=None)
    c =plt.colorbar()

# %%
data = np.loadtxt("aktuell.txt")
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title(nam)
plt.imshow(data, interpolation=None)
c =plt.colorbar()

# %%
data = np.loadtxt("/home/marszal/Projects/Num_Str_final/tests/0.2_2_5_5_0.0002_0.txt")
plt.imshow(data)
c =plt.colorbar()

# %%
data = np.loadtxt("iterationszahl.txt")
plt.plot(data[:,0],data[:,1])
print data[-1]
# Out:
# [  9.00000000e-01   1.23100000e+03]
