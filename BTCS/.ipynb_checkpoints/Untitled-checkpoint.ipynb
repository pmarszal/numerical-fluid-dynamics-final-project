# %%
import matplotlib
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.loadtxt("test.txt")
plt.imshow(data)
c =plt.colorbar()

# %%
data = np.loadtxt("iterationszahl.txt")
print data
# Out:
# []
